# %%
using PyPlot
# Out:
# INFO: Loading help data...

# %%
using PyPlot

# %% [markdown]
# ###Sistemi autonomi.

# %%
x0 = [1, 1]
h = 0.25
# Out:
# 0.25

# %%
function esempio1(t, x0)
    x = x0[1]
    y = x0[2]
    return [y, -x + (1 - x^2)*y]
end
# Out:
# esempio1 (generic function with 1 method)

# %%
x0 = [1, 1]
t0 = 0
h = 0.25
N = 50

function euler(t0, x0, h, N, f)
    t_attuale = t0
    x_attuale = x0

    ts = Float64[t_attuale]
    xs = Vector{Float64}[[x_attuale]]

    for i in 1:h:N
        push!(ts, t_attuale)
        push!(xs, x_attuale)

        t_nuova = t_attuale + h
        x_nuova = x_attuale + h*f(t_attuale, x_attuale)

        t_attuale = t_nuova
        x_attuale = x_nuova
    end
    #ts, hcat(xs...)'
    assi = hcat(xs...)'
    soluzione_x = assi[:, 1]
    soluzione_y = assi[:, 2]
    fig = figure("pyplot_subplot_mixed", figsize = (14, 7))
    subplot(131)
    plot(ts, soluzione_x)
    title("Soluzione x(t)")
    xlabel(L"t")
    ylabel(L"x(t)")
    subplot(132)
    title("Soluzione y(t)")
    xlabel(L"t")
    ylabel(L"y(t)")
    plot(ts, soluzione_y)
    subplot(133)
    title("Spazio delle fasi")
    plot(soluzione_x, soluzione_y)
    xlabel(L"x(t)")
    ylabel(L"y(t)")
    grid("on")
    
    
end
# Out:
# euler (generic function with 1 method)

# %%
euler(t0, x0, h, N, esempio1)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f14b33c6550>)
